# %%
import pandas as pd

# %%
df= pd.read_csv('data.csv')

# %%
df[(df['propertyType'] == 'Apartment') & (df['typeOfArea'] == 'Land')]
# Out:
#        area floorRange typeOfSale    price propertyType typeOfArea mktSegment  \
# 3      77.0      36-40   Sub Sale  1940000    Apartment     Strata        RCR
# 4      93.0      01-05     Resale  1500000    Apartment     Strata        RCR
# 5      40.0      06-10     Resale   930000    Apartment     Strata        RCR
# 10     81.0      31-35     Resale  2070000    Apartment     Strata        RCR
# 12     83.0      01-05     Resale  1600000    Apartment     Strata        RCR
# ...     ...        ...        ...      ...          ...        ...        ...
# 3515   90.0      01-05     Resale  1270000    Apartment     Strata        OCR
# 3517  119.0      01-05     Resale  1430000    Apartment     Strata        RCR
# 3518   42.0      01-05     Resale   750000    Apartment     Strata        OCR
# 3520  182.0      01-05     Resale  2080000    Apartment     Strata        RCR
# 3537   76.0      01-05     Resale  1100000    Apartment     Strata        OCR
#
#       Year      region
# ...
